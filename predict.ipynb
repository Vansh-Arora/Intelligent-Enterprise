# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
csv_path = "F:\\Intern\\SEASON_PREDICTIONS.csv"
season_df = pd.read_csv(csv_path)

# %%
season_df.drop("product_id", axis=1,inplace=True)
season_df
# Out:
#          product_category_name        Date  Season  year
# 0                   perfumaria  2018-04-30  Spring  2018
# 1                        artes  2018-02-06  Winter  2018
# 2                esporte_lazer  2018-07-11  Summer  2018
# 3                        bebes  2018-08-07  Summer  2018
# 4        utilidades_domesticas  2018-04-17  Spring  2018
# ...                        ...         ...     ...   ...
# 112645  informatica_acessorios  2018-01-10  Winter  2018
# 112646  informatica_acessorios  2018-03-14  Spring  2018
# 112647  informatica_acessorios  2018-03-14  Spring  2018
# 112648  informatica_acessorios  2018-03-14  Spring  2018
# 112649         cama_mesa_banho  2018-07-02  Summer  2018
#
# [112650 rows x 4 columns]

# %%
season_df.isnull().sum()
# Out:
# product_category_name    1603
# Date                        0
# Season                      0
# year                        0
# dtype: int64

# %%
season_df.dropna(inplace=True)

# %%
season_df.isnull().sum()
# Out:
# product_category_name    0
# Date                     0
# Season                   0
# year                     0
# dtype: int64

# %%
sns.pairplot(season_df)

# %%
cor_matrix = season_df.corr()
plt.figure(figsize=(12,12))
sns.heatmap(cor_matrix, annot=True)
plt.show()

# %%
season_df.hist(bins = 30, figsize=(20,20))
# Out:
# array([[<AxesSubplot:title={'center':'year'}>]], dtype=object)
